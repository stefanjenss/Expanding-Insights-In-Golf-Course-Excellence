# %%
# !pip install -U "tensorflow-text==2.13.*"
# !pip install "tf-models-official==2.13.*"
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-text==2.13.* (from versions: 2.17.0rc0, 2.17.0)
# ERROR: No matching distribution found for tensorflow-text==2.13.*
# Collecting tf-models-official==2.13.*
#   Using cached tf_models_official-2.13.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: Cython in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (3.0.11)
# Requirement already satisfied: Pillow in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (10.3.0)
# Requirement already satisfied: gin-config in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (2.140.0)
# Requirement already satisfied: immutabledict in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (4.2.0)
# Requirement already satisfied: kaggle>=1.3.9 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (1.6.17)
# Requirement already satisfied: matplotlib in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (3.8.4)
# Requirement already satisfied: numpy>=1.20 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (1.23.5)
# Requirement already satisfied: oauth2client in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (4.10.0.84)
# Requirement already satisfied: pandas>=0.22.0 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (2.2.2)
# Requirement already satisfied: psutil>=5.4.3 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (5.9.0)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (9.0.0)
# Requirement already satisfied: pycocotools in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (2.0.8)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (6.0.1)
# Requirement already satisfied: sacrebleu in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (2.4.2)
# Requirement already satisfied: scipy>=0.19.1 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (1.10.1)
# Requirement already satisfied: sentencepiece in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (0.2.0)
# Requirement already satisfied: seqeval in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (1.2.2)
# Requirement already satisfied: six in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (1.16.0)
# Requirement already satisfied: tensorflow-datasets in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (4.9.6)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages (from tf-models-official==2.13.*) (0.8.0)
# INFO: pip is looking at multiple versions of tf-models-official to determine which version is compatible with other requirements. This could take a while.
#   Using cached tf_models_official-2.13.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyyaml<5.4.0,>=5.1 (from tf-models-official==2.13.*)
#   Using cached PyYAML-5.3.1.tar.gz (269 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [37 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/t2/xw_g33n96rxfmq14n3dnpb6h0000gn/T/pip-install-_ndmcgd5/pyyaml_59600574cb734785a4400e0e7d1adb4d/setup.py", line 291, in <module>
#           setup(
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 184, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 200, in run_commands
#           dist.run_commands()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/dist.py", line 967, in run_command
#           super().run_command(command)
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 321, in run
#           self.find_sources()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 329, in find_sources
#           mm.run()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 550, in run
#           self.add_defaults()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 588, in add_defaults
#           sdist.add_defaults(self)
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/command/sdist.py", line 102, in add_defaults
#           super().add_defaults()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 250, in add_defaults
#           self._add_defaults_ext()
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 335, in _add_defaults_ext
#           self.filelist.extend(build_ext.get_source_files())
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/t2/xw_g33n96rxfmq14n3dnpb6h0000gn/T/pip-install-_ndmcgd5/pyyaml_59600574cb734785a4400e0e7d1adb4d/setup.py", line 199, in get_source_files
#           self.cython_sources(ext.sources, ext)
#           ^^^^^^^^^^^^^^^^^^^
#         File "/Users/stefanjenss/anaconda3/envs/AI-DL/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 107, in __getattr__
#           raise AttributeError(attr)
#       AttributeError: cython_sources
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd

df = pd.read_csv("top_and_non_golf_course_reviews.csv")
df.head()
# Out:
#    review_id       course_name   label          location  \
# 0          1       Pine Valley  top100   Pine Valley, NJ
# 1          2       Pine Valley  top100   Pine Valley, NJ
# 2          3     Cypress Point  top100  Pebble Beach, CA
# 3          4     Cypress Point  top100  Pebble Beach, CA
# 4          5  Shinnecock Hills  top100   Southampton, NY
#
#                       architect  year_built  \
# 0  George Crump / Harry S. Colt        1918
# 1  George Crump / Harry S. Colt        1918
# 2             Alister MacKenzie        1928
# 3             Alister MacKenzie        1928
# 4                 William Flynn        1931
#
#                                         review_title     review_author  \
# 0                  PINE VALLEY GOLF CLUB - 19 POINTS       David Jones
# 1      Pine Valley Golf Club (Clementon, New Jersey)  Bill Satterfield
# 2                               CYPRESS POINT REVIEW    Graylyn Loomis
# 3  Cypress Point Golf Club (Pebble Beach, Califor...  Bill Satterfield
# 4                 Review: Shinnecock Hills Golf Club     Andrew Harvie
#
#                file_name                                        review_text
# 0    rev01_pine_valley_1  There’s not much point trying to do a hole-by-...
# 1    rev02_pine_valley_2  What to Expect:  Pine Valley is the finest gol...
# 2  rev03_cypress_point_1  “No one but a poet should be allowed to write ...
# 3  rev04_cypress_point_2  What to Expect:  I don't even feel worthy to w...
# 4     rev05_shinnecock_1  There’s not many courses as acclaimed, sought ...

# %%
df.groupby('label').count()
# Out:
#         review_id  course_name  location  architect  year_built  review_title  \
# label
# non100         60           60        60         60          60            60
# top100         60           60        60         60          60            60
#
#         review_author  file_name  review_text
# label
# non100             60         60           60
# top100             60         60           60

# %%
df.groupby('label').describe()
# Out:
#        review_id                                                     \
#            count  mean        std   min    25%   50%     75%    max
# label
# non100      60.0  90.5  17.464249  61.0  75.75  90.5  105.25  120.0
# top100      60.0  30.5  17.464249   1.0  15.75  30.5   45.25   60.0
#
#        year_built                                                          \
#             count         mean        std     min     25%     50%     75%
# label
# non100       60.0  1989.666667  27.972545  1897.0  1989.0  1999.5  2003.0
# top100       60.0  1928.266667  26.483040  1895.0  1917.0  1924.5  1932.0
#
#
#            max
# label
# non100  2019.0
# top100  2003.0

# %%
df['top100'] = df['label'].apply(lambda x: 1 if x == 'top100' else 0)
df.head(3)
df.tail(3)
# Out:
#      review_id            course_name   label         location    architect  \
# 117        118          Blackwolf Run  non100       Kohler, WI     Pete Dye
# 118        119  Black Creek Golf Club  non100  Chattanooga, TN  Brian Silva
# 119        120  Black Creek Golf Club  non100  Chattanooga, TN  Brian Silva
#
#      year_built                                    review_title  \
# 117        1989  Golf Course Review: The River at Blackwolf Run
# 118        2000  Black Creek Golf Club (Chattanooga, Tennessee)
# 119        2000                                BLACK CREEK CLUB
#
#         review_author                  file_name  \
# 117        Derek Wise     rev118_blackwolf_run_2
# 118  Bill Satterfield  rev119_black_creek_club_1
# 119        Phil Sokol  rev120_black_creek_club_2
#
#                                            review_text  top100
# 117  The River at Blackwolf Run golf course has bee...       0
# 118  What to Expect:  Black Creek is a throwback in...       0
# 119  HISTORY:  When a  course is  only open  for a ...       0

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %%
def get_review_embedding(reviews):
    preprocessed_text = bert_preprocess(reviews)
    return bert_encoder(preprocessed_text)['pooled_output']

# %%
# Example of how the get_review_embedding function works
get_review_embedding(["There’s not much point trying to do a hole-by", "No one but a poet should be allowed to write"])
# Out:
# <tf.Tensor: shape=(2, 768), dtype=float32, numpy=
# array([[-0.7295202 , -0.17719838,  0.1491849 , ...,  0.07682879,
#         -0.56339663,  0.8735246 ],
#        [-0.84179395, -0.44324878, -0.6954385 , ..., -0.34175068,
#         -0.72697586,  0.7802301 ]], dtype=float32)>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['review_text'], df['top100'], test_size=0.2, stratify=df['top100'], random_state=42)

# %%
X_train.head()
# Out:
# 11    The Sandhills region of Nebraska is a huge mea...
# 77    Designed by Tom Fazio and opened in 1987, the ...
# 52    The California Golf Club of San Francisco date...
# 66    The Myrtle Beach area, known as the “Grand Str...
# 32    “One is a curiosity, two is a destination.” Mi...
# Name: review_text, dtype: object

# %%
bert_preprocess = hub.KerasLayer("https://www.kaggle.com/models/tensorflow/bert/tensorFlow2/en-uncased-preprocess/3")
bert_encoder = hub.KerasLayer("https://www.kaggle.com/models/tensorflow/bert/tensorFlow2/en-uncased-l-12-h-768-a-12/4")

# %%
def get_review_embedding(reviews):
    preprocessed_text = bert_preprocess(reviews)
    return bert_encoder(preprocessed_text)['pooled_output']

# %%
from tensorflow.keras.utils import plot_model

# %%
# Bert Layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name="text")
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# Neural network layers
l = tf.keras.layers.Dropout(0.1, name='dropout')(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation = 'sigmoid', name = 'output')(l)

# Construct the final model
model = tf.keras.Model(inputs=[text_input], outputs=[l])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Bert Layers
#       2 text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name="text")
# ----> 3 preprocessed_text = bert_preprocess(text_input)
#       4 outputs = bert_encoder(preprocessed_text)
#       6 # Neural network layers
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tensorflow_hub/keras_layer.py:250, in KerasLayer.call(self, inputs, training)
#     247   else:
#     248     # Behave like BatchNormalization. (Dropout is different, b/181839368.)
#     249     training = False
# --> 250   result = smart_cond.smart_cond(training,
#     251                                  lambda: f(training=True),
#     252                                  lambda: f(training=False))
#     254 # Unwrap dicts returned by signatures.
#     255 if self._output_key:
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tensorflow_hub/keras_layer.py:252, in KerasLayer.call.<locals>.<lambda>()
#     247   else:
#     248     # Behave like BatchNormalization. (Dropout is different, b/181839368.)
#     249     training = False
#     250   result = smart_cond.smart_cond(training,
#     251                                  lambda: f(training=True),
# --> 252                                  lambda: f(training=False))
#     254 # Unwrap dicts returned by signatures.
#     255 if self._output_key:
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tensorflow/core/function/polymorphism/function_type.py:583, in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     577       parameters.append(
#     578           _make_validated_mono_param(kwarg_name, arg[kwarg_name],
#     579                                      Parameter.KEYWORD_ONLY, type_context,
#     580                                      poly_parameter.type_constraint))
#     581   else:
#     582     parameters.append(
# --> 583         _make_validated_mono_param(name, arg, poly_parameter.kind,
#     584                                    type_context,
#     585                                    poly_parameter.type_constraint))
#     587 return FunctionType(parameters, capture_types), type_context
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tensorflow/core/function/polymorphism/function_type.py:522, in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     518 def _make_validated_mono_param(
#     519     name, value, kind, type_context, poly_type
#     520 ) -> Parameter:
#     521   """Generates and validates a parameter for Monomorphic FunctionType."""
# --> 522   mono_type = trace_type.from_value(value, type_context)
#     524   if poly_type and not mono_type.is_subtype_of(poly_type):
#     525     raise TypeError(f"Parameter `{name}` was expected to be of type "
#     526                     f"{poly_type} but is {mono_type}")
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/tensorflow/core/function/trace_type/trace_type_builder.py:185, in from_value(value, context)
#     178   return default_types.Attrs.from_type_and_attributes(
#     179       type(value),
#     180       tuple(
#     181           from_value(getattr(value, a.name), context)
#     182           for a in value.__attrs_attrs__))
#     184 if util.is_np_ndarray(value):
# --> 185   ndarray = value.__array__()
#     186   return default_types.TENSOR(ndarray.shape, ndarray.dtype)
#     188 if isinstance(value, custom_nest_protocol.CustomNestProtocol):
#
# File ~/anaconda3/envs/AI-DL/lib/python3.11/site-packages/keras/src/backend/common/keras_tensor.py:61, in KerasTensor.__array__(self)
#      60 def __array__(self):
# ---> 61     raise ValueError(
#      62         "A KerasTensor is symbolic: it's a placeholder for a shape "
#      63         "an a dtype. It doesn't have any actual numerical value. "
#      64         "You cannot convert it to a NumPy array."
#      65     )
#
# ValueError: Exception encountered when calling layer 'keras_layer_2' (type KerasLayer).
#
# A KerasTensor is symbolic: it's a placeholder for a shape an a dtype. It doesn't have any actual numerical value. You cannot convert it to a NumPy array.
#
# Call arguments received by layer 'keras_layer_2' (type KerasLayer):
#   • inputs=<KerasTensor shape=(None,), dtype=string, sparse=None, name=text>
#   • training=None

# %%
# Bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# Neural Network Layers
l = tf.keras.layers.Dropout(0.1, name = 'dropout')(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation = 'sigmoid', name = 'output')(l)

# Use the inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])
